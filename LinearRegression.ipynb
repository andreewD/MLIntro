# %% [markdown]
# <a href="https://colab.research.google.com/github/andreewD/MLIntro/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
boston =load_boston()
#print(boston.DESCR)

# %%
X = np.array(boston.data[:,5])
Y = np.array(boston.target)

plt.scatter(X,Y,alpha=0.3)
plt.xlabel("Average")
plt.ylabel("Price")
#plt.show
l_x=len(X)
X=np.array([np.ones(l_x),X]).T
B=np.linalg.inv(X.T@X)@X.T@Y
#EL "@" SE USA PARA MULTIPLICAR MATRICES ( NUMPY)
print(B)
plt.plot([4,9],[B[0]+B[1]*4,B[0]+B[1]*9],c="r")
plt.show
# Out:
# [-34.67062078   9.10210898]
# <function matplotlib.pyplot.show>
